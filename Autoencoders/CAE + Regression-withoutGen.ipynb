# %%
from keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D, UpSampling2D, LeakyReLU, BatchNormalization, Conv2DTranspose
from keras.models import Model
from keras import backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, History
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

import numpy as np
from PIL import Image
import math
import os 
# from numba import cuda
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.python.client import device_lib
from sklearn import metrics
from sklearn.cluster import KMeans
from skimage.color import rgb2hed
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import metrics
import pandas as pd

import cv2
import newscripts as myutils

# %%
gpu_options = tf.GPUOptions(allow_growth=True)
custom_config=tf.ConfigProto(log_device_placement=True, allow_soft_placement=True, gpu_options=gpu_options)
custom_config.gpu_options.allocator_type = 'BFC'
custom_config.gpu_options.per_process_gpu_memory_fraction = 0.90
session = tf.InteractiveSession(config=custom_config)

device_lib.list_local_devices()
# Out:
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 10196260007878915630, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7730941132
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1623025845773963065
#  physical_device_desc: "device: 0, name: GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
## Images loading 
datadir = "C:/Users/mostafaosama2/Desktop/autoenctrain/60k"

trainData = datadir + "/train"
testData = datadir + "/test"

n_training_samples = len(trainData) 
n_testing_samples = len(testData)

new_train = []
new_test = []
train_image_names = []
test_image_names = []

for filename in os.listdir(trainData):
    if filename.endswith('.tif'):
        image = cv2.imread(os.path.join(trainData, filename), cv2.IMREAD_UNCHANGED)
        resized_image = cv2.resize(image, (96, 96)) 
        new_train.append(np.asarray( resized_image, dtype="uint8" ))
        train_image_names.append(filename)

for filename in os.listdir(testData):
    if filename.endswith('.tif'):
        image = cv2.imread(os.path.join(testData, filename), cv2.IMREAD_UNCHANGED)
        resized_image = cv2.resize(image, (96, 96))
        new_test.append(np.asarray( resized_image, dtype="uint8" ))
        test_image_names.append(filename)

## Data preprocessing

x_train = np.asarray(new_train)
x_test = np.asarray(new_test)
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0600a67f82f1> in <module>
#      22 for filename in os.listdir(testData):
#      23     if filename.endswith('.tif'):
# ---> 24         image = cv2.imread(os.path.join(testData, filename), cv2.IMREAD_UNCHANGED)
#      25         resized_image = cv2.resize(image, (96, 96))
#      26         new_test.append(np.asarray( resized_image, dtype="uint8" ))
#
# KeyboardInterrupt:

# %%
n_epochs = 200
batch_size = 32
adam = Adam(lr=0.0008, beta_1=0.9, beta_2=0.999, amsgrad=False)
optimizer = adam
loss1 = 'mean_squared_error'
loss2 = 'mean_squared_error'

input_img = Input(shape=(96, 96, 3))  # adapt this if using `channels_first` image data format

encoder = Conv2D(filters=16, kernel_size=(3,3),strides=1, padding='same')(input_img)#x^2*16
encoder = LeakyReLU()(encoder)
encoder = Conv2D(filters=32, kernel_size=(3,3),strides=1, padding='same')(encoder)#x^2*32
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = Conv2D(filters=64, kernel_size=(3,3),strides=2, padding='same')(encoder)#(x/2)^2*64
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = MaxPooling2D()(encoder)#(x/4)^2*64
encoder = Conv2D(filters=128, kernel_size=(3,3),strides=2, padding='same')(encoder)#(x/8)^2*128
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = MaxPooling2D()(encoder)#(x/16)^2*64
encoder = Conv2D(filters=64, kernel_size=(3,3),strides=1, padding='same')(encoder)#(x/16)^2*64
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = Conv2D(filters=32, kernel_size=(3,3),strides=1, padding='same')(encoder)#(x/16)^2*32
encoder = LeakyReLU()(encoder)


bottleneck = Conv2D(filters=32, kernel_size=(1,1),strides=1, padding='same')(encoder)#(x/16)^2*16
bottleneck = LeakyReLU()(bottleneck)


decoder = Conv2D(filters=32, kernel_size=(1,1),strides=1, padding='same')(bottleneck)#(x/16)^2*32
decoder = LeakyReLU()(decoder)
decoder = Conv2D(filters=64, kernel_size=(3,3),strides=1, padding='same')(decoder)#(x/16)^2*64
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D()(decoder)#(x/8)^2*64
decoder = Conv2DTranspose(filters=128, kernel_size=(3,3),strides=2, padding='same')(decoder)#(x/4)^2*128
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D()(decoder)#(x/2)^2*128
decoder = Conv2DTranspose(filters=64, kernel_size=(3,3),strides=2, padding='same')(decoder)#x^2*64
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = Conv2D(filters=32, kernel_size=(3,3),strides=1, padding='same')(decoder)#x^2*32
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = Conv2D(filters=16, kernel_size=(3,3),strides=1, padding='same')(decoder)#x^2*16
decoder = LeakyReLU()(decoder)
decoder = Conv2D(filters=3, kernel_size=(3,3),strides=1, padding='same')(decoder)#x^2*3
decoded = LeakyReLU()(decoder)

regressor = Flatten()(bottleneck)
regressor = Dense(128)(regressor) 
regressor = LeakyReLU()(regressor)
regressor = BatchNormalization()(regressor)
regressor = Dense(64)(regressor) 
regressor = LeakyReLU()(regressor)
regressor = BatchNormalization()(regressor)
regressor = Dense(32)(regressor) 
regressor = LeakyReLU()(regressor)
regressor = BatchNormalization()(regressor)
regressor = Dense(1, activation='sigmoid')(regressor) # add batch norm
# exploding gradients
#weight decay or momentum

autoencoder = Model(input_img, [decoded, regressor])
autoencoder.compile(optimizer=optimizer , loss=[loss1,loss2])

mainDr = "C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/"
filepath = mainDr + "{}_epochs{}_batch{}.h5".format(loss2, n_epochs,batch_size)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
ES = EarlyStopping(monitor='val_loss', min_delta=0, patience=30, mode='min', verbose=0, restore_best_weights=True)
csv_logger = CSVLogger('training.log')
callbacks_list = [checkpoint, ES, csv_logger]

autoencoder.summary()

# %%
# csvFilePath = "C:/Users/mostafaosama2/Desktop/Kaggle-Data/train_labels.csv"
# df = pd.read_csv(csvFilePath)
# trainlabels = []
# testlabels = []

# for image in train_image_names:
#     label_index = df[df["id"] == image.split(".")[0]].index[0]
#     trainlabels.append(df["label"][label_index])
    
# for image in test_image_names:
#     label_index = df[df["id"] == image.split(".")[0]].index[0]
#     testlabels.append(df["label"][label_index])

labels_directory = "C:/Users/mostafaosama2/Desktop/autoenctrain/kather_labels"
trainlabels = myutils.loadLabelsFromsubdirectoryindex(train_image_names, labels_directory)
testlabels = myutils.loadLabelsFromsubdirectoryindex(test_image_names, labels_directory)

# %%
trainlabels = np.asarray(trainlabels)
testlabels = np.asarray(testlabels)
print(x_train.shape)
print(x_test.shape)
print(trainlabels.shape)
print(testlabels.shape)
# Out:
# (45000, 96, 96, 3)
# (15000, 96, 96, 3)
# (45000,)
# (15000,)

# %%
with tf.device('/GPU:0'):
    autoencoder_train = autoencoder.fit(
                    x_train, 
                    [x_train, trainlabels],
                    epochs=n_epochs,
                    batch_size=batch_size,
                    validation_data=(x_test, [x_test, testlabels]),
                    callbacks=callbacks_list
                   )
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/300
# 45000/45000 [==============================] - 242s 5ms/step - loss: 0.1707 - leaky_re_lu_167_loss: 0.0441 - dense_40_loss: 0.1266 - val_loss: 0.1752 - val_leaky_re_lu_167_loss: 0.0341 - val_dense_40_loss: 0.1411
#
# Epoch 00001: val_loss improved from inf to 0.17521, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/mean_squared_error_epochs300_batch64.h5
# Epoch 2/300
# 45000/45000 [==============================] - 205s 5ms/step - loss: 0.1393 - leaky_re_lu_167_loss: 0.0332 - dense_40_loss: 0.1062 - val_loss: 0.3545 - val_leaky_re_lu_167_loss: 0.0372 - val_dense_40_loss: 0.3173
#
# Epoch 00002: val_loss did not improve from 0.17521
# Epoch 3/300
# 45000/45000 [==============================] - 191s 4ms/step - loss: 0.1296 - leaky_re_lu_167_loss: 0.0323 - dense_40_loss: 0.0973 - val_loss: 0.2471 - val_leaky_re_lu_167_loss: 0.0347 - val_dense_40_loss: 0.2125
#
# Epoch 00003: val_loss did not improve from 0.17521
# Epoch 4/300
# 45000/45000 [==============================] - 200s 4ms/step - loss: 0.1207 - leaky_re_lu_167_loss: 0.0317 - dense_40_loss: 0.0890 - val_loss: 0.1476 - val_leaky_re_lu_167_loss: 0.0394 - val_dense_40_loss: 0.1082
#
# Epoch 00004: val_loss improved from 0.17521 to 0.14758, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/mean_squared_error_epochs300_batch64.h5
# Epoch 5/300
# 45000/45000 [==============================] - 182s 4ms/step - loss: 0.1128 - leaky_re_lu_167_loss: 0.0313 - dense_40_loss: 0.0815 - val_loss: 0.1974 - val_leaky_re_lu_167_loss: 0.0324 - val_dense_40_loss: 0.1650
#
# Epoch 00005: val_loss did not improve from 0.14758
# Epoch 6/300
# 45000/45000 [==============================] - 188s 4ms/step - loss: 0.1069 - leaky_re_lu_167_loss: 0.0310 - dense_40_loss: 0.0759 - val_loss: 0.3359 - val_leaky_re_lu_167_loss: 0.0360 - val_dense_40_loss: 0.2999
#
# Epoch 00006: val_loss did not improve from 0.14758
# Epoch 7/300
# 45000/45000 [==============================] - 188s 4ms/step - loss: 0.1006 - leaky_re_lu_167_loss: 0.0307 - dense_40_loss: 0.0699 - val_loss: 0.2251 - val_leaky_re_lu_167_loss: 0.0364 - val_dense_40_loss: 0.1887
#
# Epoch 00007: val_loss did not improve from 0.14758
# Epoch 8/300
# 45000/45000 [==============================] - 191s 4ms/step - loss: 0.0937 - leaky_re_lu_167_loss: 0.0305 - dense_40_loss: 0.0632 - val_loss: 0.2548 - val_leaky_re_lu_167_loss: 0.0355 - val_dense_40_loss: 0.2193
#
# Epoch 00008: val_loss did not improve from 0.14758
# Epoch 9/300
# 45000/45000 [==============================] - 195s 4ms/step - loss: 0.0875 - leaky_re_lu_167_loss: 0.0304 - dense_40_loss: 0.0572 - val_loss: 0.1476 - val_leaky_re_lu_167_loss: 0.0325 - val_dense_40_loss: 0.1150
#
# Epoch 00009: val_loss improved from 0.14758 to 0.14755, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/mean_squared_error_epochs300_batch64.h5
# Epoch 10/300
# 45000/45000 [==============================] - 192s 4ms/step - loss: 0.0805 - leaky_re_lu_167_loss: 0.0303 - dense_40_loss: 0.0502 - val_loss: 0.1192 - val_leaky_re_lu_167_loss: 0.0329 - val_dense_40_loss: 0.0863
#
# Epoch 00010: val_loss improved from 0.14755 to 0.11920, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/mean_squared_error_epochs300_batch64.h5
# Epoch 11/300
# 45000/45000 [==============================] - 192s 4ms/step - loss: 0.0763 - leaky_re_lu_167_loss: 0.0301 - dense_40_loss: 0.0461 - val_loss: 0.2054 - val_leaky_re_lu_167_loss: 0.0318 - val_dense_40_loss: 0.1736
#
# Epoch 00011: val_loss did not improve from 0.11920
# Epoch 12/300
# 45000/45000 [==============================] - 193s 4ms/step - loss: 0.0720 - leaky_re_lu_167_loss: 0.0300 - dense_40_loss: 0.0420 - val_loss: 0.1893 - val_leaky_re_lu_167_loss: 0.0328 - val_dense_40_loss: 0.1566
#
# Epoch 00012: val_loss did not improve from 0.11920
# Epoch 13/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0652 - leaky_re_lu_167_loss: 0.0298 - dense_40_loss: 0.0353 - val_loss: 0.1298 - val_leaky_re_lu_167_loss: 0.0344 - val_dense_40_loss: 0.0954
#
# Epoch 00013: val_loss did not improve from 0.11920
# Epoch 14/300
# 45000/45000 [==============================] - 187s 4ms/step - loss: 0.0642 - leaky_re_lu_167_loss: 0.0299 - dense_40_loss: 0.0344 - val_loss: 0.3051 - val_leaky_re_lu_167_loss: 0.0308 - val_dense_40_loss: 0.2742
#
# Epoch 00014: val_loss did not improve from 0.11920
# Epoch 15/300
# 45000/45000 [==============================] - 191s 4ms/step - loss: 0.0607 - leaky_re_lu_167_loss: 0.0297 - dense_40_loss: 0.0309 - val_loss: 0.2314 - val_leaky_re_lu_167_loss: 0.0305 - val_dense_40_loss: 0.2009
#
# Epoch 00015: val_loss did not improve from 0.11920
# Epoch 16/300
# 45000/45000 [==============================] - 193s 4ms/step - loss: 0.0578 - leaky_re_lu_167_loss: 0.0297 - dense_40_loss: 0.0281 - val_loss: 0.1602 - val_leaky_re_lu_167_loss: 0.0299 - val_dense_40_loss: 0.1303
#
# Epoch 00016: val_loss did not improve from 0.11920
# Epoch 17/300
# 45000/45000 [==============================] - 193s 4ms/step - loss: 0.0555 - leaky_re_lu_167_loss: 0.0296 - dense_40_loss: 0.0259 - val_loss: 0.1441 - val_leaky_re_lu_167_loss: 0.0305 - val_dense_40_loss: 0.1136
#
# Epoch 00017: val_loss did not improve from 0.11920
# Epoch 18/300
# 45000/45000 [==============================] - 193s 4ms/step - loss: 0.0540 - leaky_re_lu_167_loss: 0.0296 - dense_40_loss: 0.0244 - val_loss: 0.2093 - val_leaky_re_lu_167_loss: 0.0304 - val_dense_40_loss: 0.1789
#
# Epoch 00018: val_loss did not improve from 0.11920
# Epoch 19/300
# 45000/45000 [==============================] - 190s 4ms/step - loss: 0.0527 - leaky_re_lu_167_loss: 0.0295 - dense_40_loss: 0.0231 - val_loss: 0.1714 - val_leaky_re_lu_167_loss: 0.0318 - val_dense_40_loss: 0.1396
#
# Epoch 00019: val_loss did not improve from 0.11920
# Epoch 20/300
# 45000/45000 [==============================] - 193s 4ms/step - loss: 0.0500 - leaky_re_lu_167_loss: 0.0295 - dense_40_loss: 0.0206 - val_loss: 0.1768 - val_leaky_re_lu_167_loss: 0.0296 - val_dense_40_loss: 0.1471
#
# Epoch 00020: val_loss did not improve from 0.11920
# Epoch 21/300
# 45000/45000 [==============================] - 188s 4ms/step - loss: 0.0482 - leaky_re_lu_167_loss: 0.0293 - dense_40_loss: 0.0189 - val_loss: 0.1497 - val_leaky_re_lu_167_loss: 0.0321 - val_dense_40_loss: 0.1176
#
# Epoch 00021: val_loss did not improve from 0.11920
# Epoch 22/300
# 45000/45000 [==============================] - 187s 4ms/step - loss: 0.0486 - leaky_re_lu_167_loss: 0.0293 - dense_40_loss: 0.0193 - val_loss: 0.1470 - val_leaky_re_lu_167_loss: 0.0301 - val_dense_40_loss: 0.1168
#
# Epoch 00022: val_loss did not improve from 0.11920
# Epoch 23/300
# 45000/45000 [==============================] - 186s 4ms/step - loss: 0.0467 - leaky_re_lu_167_loss: 0.0293 - dense_40_loss: 0.0175 - val_loss: 0.1729 - val_leaky_re_lu_167_loss: 0.0294 - val_dense_40_loss: 0.1435
#
# Epoch 00023: val_loss did not improve from 0.11920
# Epoch 24/300
# 45000/45000 [==============================] - 184s 4ms/step - loss: 0.0458 - leaky_re_lu_167_loss: 0.0292 - dense_40_loss: 0.0166 - val_loss: 0.1328 - val_leaky_re_lu_167_loss: 0.0293 - val_dense_40_loss: 0.1036
#
# Epoch 00024: val_loss did not improve from 0.11920
# Epoch 25/300
# 45000/45000 [==============================] - 195s 4ms/step - loss: 0.0443 - leaky_re_lu_167_loss: 0.0291 - dense_40_loss: 0.0152 - val_loss: 0.1547 - val_leaky_re_lu_167_loss: 0.0308 - val_dense_40_loss: 0.1239
#
# Epoch 00025: val_loss did not improve from 0.11920
# Epoch 26/300
# 45000/45000 [==============================] - 190s 4ms/step - loss: 0.0436 - leaky_re_lu_167_loss: 0.0291 - dense_40_loss: 0.0145 - val_loss: 0.1299 - val_leaky_re_lu_167_loss: 0.0311 - val_dense_40_loss: 0.0988
#
# Epoch 00026: val_loss did not improve from 0.11920
# Epoch 27/300
# 45000/45000 [==============================] - 182s 4ms/step - loss: 0.0433 - leaky_re_lu_167_loss: 0.0291 - dense_40_loss: 0.0142 - val_loss: 0.1354 - val_leaky_re_lu_167_loss: 0.0290 - val_dense_40_loss: 0.1064
#
# Epoch 00027: val_loss did not improve from 0.11920
# Epoch 28/300
# 45000/45000 [==============================] - 183s 4ms/step - loss: 0.0425 - leaky_re_lu_167_loss: 0.0290 - dense_40_loss: 0.0135 - val_loss: 0.2842 - val_leaky_re_lu_167_loss: 0.0313 - val_dense_40_loss: 0.2529
#
# Epoch 00028: val_loss did not improve from 0.11920
# Epoch 29/300
# 45000/45000 [==============================] - 185s 4ms/step - loss: 0.0422 - leaky_re_lu_167_loss: 0.0290 - dense_40_loss: 0.0133 - val_loss: 0.2181 - val_leaky_re_lu_167_loss: 0.0317 - val_dense_40_loss: 0.1864
#
# Epoch 00029: val_loss did not improve from 0.11920
# Epoch 30/300
# 45000/45000 [==============================] - 187s 4ms/step - loss: 0.0418 - leaky_re_lu_167_loss: 0.0289 - dense_40_loss: 0.0129 - val_loss: 0.1280 - val_leaky_re_lu_167_loss: 0.0291 - val_dense_40_loss: 0.0989
#
# Epoch 00030: val_loss did not improve from 0.11920
# Epoch 31/300
# 45000/45000 [==============================] - 195s 4ms/step - loss: 0.0410 - leaky_re_lu_167_loss: 0.0288 - dense_40_loss: 0.0122 - val_loss: 0.3181 - val_leaky_re_lu_167_loss: 0.0316 - val_dense_40_loss: 0.2865
#
# Epoch 00031: val_loss did not improve from 0.11920
# Epoch 32/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0424 - leaky_re_lu_167_loss: 0.0288 - dense_40_loss: 0.0135 - val_loss: 0.1233 - val_leaky_re_lu_167_loss: 0.0293 - val_dense_40_loss: 0.0940
#
# Epoch 00032: val_loss did not improve from 0.11920
# Epoch 33/300
# 45000/45000 [==============================] - 193s 4ms/step - loss: 0.0385 - leaky_re_lu_167_loss: 0.0287 - dense_40_loss: 0.0098 - val_loss: 0.3152 - val_leaky_re_lu_167_loss: 0.0308 - val_dense_40_loss: 0.2844
#
# Epoch 00033: val_loss did not improve from 0.11920
# Epoch 34/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0405 - leaky_re_lu_167_loss: 0.0287 - dense_40_loss: 0.0118 - val_loss: 0.1422 - val_leaky_re_lu_167_loss: 0.0297 - val_dense_40_loss: 0.1125
#
# Epoch 00034: val_loss did not improve from 0.11920
# Epoch 35/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0398 - leaky_re_lu_167_loss: 0.0287 - dense_40_loss: 0.0112 - val_loss: 0.1299 - val_leaky_re_lu_167_loss: 0.0289 - val_dense_40_loss: 0.1010
#
# Epoch 00035: val_loss did not improve from 0.11920
# Epoch 36/300
# 45000/45000 [==============================] - 190s 4ms/step - loss: 0.0393 - leaky_re_lu_167_loss: 0.0286 - dense_40_loss: 0.0106 - val_loss: 0.1901 - val_leaky_re_lu_167_loss: 0.0297 - val_dense_40_loss: 0.1605
#
# Epoch 00036: val_loss did not improve from 0.11920
# Epoch 37/300
# 45000/45000 [==============================] - 182s 4ms/step - loss: 0.0385 - leaky_re_lu_167_loss: 0.0285 - dense_40_loss: 0.0099 - val_loss: 0.1829 - val_leaky_re_lu_167_loss: 0.0287 - val_dense_40_loss: 0.1542
#
# Epoch 00037: val_loss did not improve from 0.11920
# Epoch 38/300
# 45000/45000 [==============================] - 191s 4ms/step - loss: 0.0381 - leaky_re_lu_167_loss: 0.0285 - dense_40_loss: 0.0096 - val_loss: 0.1580 - val_leaky_re_lu_167_loss: 0.0289 - val_dense_40_loss: 0.1291
#
# Epoch 00038: val_loss did not improve from 0.11920
# Epoch 39/300
# 45000/45000 [==============================] - 197s 4ms/step - loss: 0.0392 - leaky_re_lu_167_loss: 0.0285 - dense_40_loss: 0.0107 - val_loss: 0.1156 - val_leaky_re_lu_167_loss: 0.0287 - val_dense_40_loss: 0.0869
#
# Epoch 00039: val_loss improved from 0.11920 to 0.11565, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/mean_squared_error_epochs300_batch64.h5
# Epoch 40/300
# 45000/45000 [==============================] - 184s 4ms/step - loss: 0.0366 - leaky_re_lu_167_loss: 0.0284 - dense_40_loss: 0.0082 - val_loss: 0.1534 - val_leaky_re_lu_167_loss: 0.0286 - val_dense_40_loss: 0.1248
#
# Epoch 00040: val_loss did not improve from 0.11565
# Epoch 41/300
# 45000/45000 [==============================] - 191s 4ms/step - loss: 0.0367 - leaky_re_lu_167_loss: 0.0283 - dense_40_loss: 0.0084 - val_loss: 0.1492 - val_leaky_re_lu_167_loss: 0.0286 - val_dense_40_loss: 0.1206
#
# Epoch 00041: val_loss did not improve from 0.11565
# Epoch 42/300
# 45000/45000 [==============================] - 189s 4ms/step - loss: 0.0373 - leaky_re_lu_167_loss: 0.0283 - dense_40_loss: 0.0090 - val_loss: 0.2123 - val_leaky_re_lu_167_loss: 0.0291 - val_dense_40_loss: 0.1832
#
# Epoch 00042: val_loss did not improve from 0.11565
# Epoch 43/300
# 45000/45000 [==============================] - 191s 4ms/step - loss: 0.0365 - leaky_re_lu_167_loss: 0.0283 - dense_40_loss: 0.0082 - val_loss: 0.1425 - val_leaky_re_lu_167_loss: 0.0284 - val_dense_40_loss: 0.1141
#
# Epoch 00043: val_loss did not improve from 0.11565
# Epoch 44/300
# 45000/45000 [==============================] - 188s 4ms/step - loss: 0.0379 - leaky_re_lu_167_loss: 0.0282 - dense_40_loss: 0.0097 - val_loss: 0.1401 - val_leaky_re_lu_167_loss: 0.0287 - val_dense_40_loss: 0.1114
#
# Epoch 00044: val_loss did not improve from 0.11565
# Epoch 45/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0391 - leaky_re_lu_167_loss: 0.0282 - dense_40_loss: 0.0109 - val_loss: 0.1787 - val_leaky_re_lu_167_loss: 0.0307 - val_dense_40_loss: 0.1480
#
# Epoch 00045: val_loss did not improve from 0.11565
# Epoch 46/300
# 45000/45000 [==============================] - 192s 4ms/step - loss: 0.0367 - leaky_re_lu_167_loss: 0.0281 - dense_40_loss: 0.0085 - val_loss: 0.1329 - val_leaky_re_lu_167_loss: 0.0285 - val_dense_40_loss: 0.1045
#
# Epoch 00046: val_loss did not improve from 0.11565
# Epoch 47/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0390 - leaky_re_lu_167_loss: 0.0283 - dense_40_loss: 0.0108 - val_loss: 0.1314 - val_leaky_re_lu_167_loss: 0.0287 - val_dense_40_loss: 0.1027
#
# Epoch 00047: val_loss did not improve from 0.11565
# Epoch 48/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0351 - leaky_re_lu_167_loss: 0.0280 - dense_40_loss: 0.0070 - val_loss: 0.1190 - val_leaky_re_lu_167_loss: 0.0296 - val_dense_40_loss: 0.0895
#
# Epoch 00048: val_loss did not improve from 0.11565
# Epoch 49/300
# 45000/45000 [==============================] - 192s 4ms/step - loss: 0.0357 - leaky_re_lu_167_loss: 0.0280 - dense_40_loss: 0.0078 - val_loss: 0.1240 - val_leaky_re_lu_167_loss: 0.0280 - val_dense_40_loss: 0.0960
#
# Epoch 00049: val_loss did not improve from 0.11565
# Epoch 50/300
# 45000/45000 [==============================] - 197s 4ms/step - loss: 0.0358 - leaky_re_lu_167_loss: 0.0280 - dense_40_loss: 0.0078 - val_loss: 0.1478 - val_leaky_re_lu_167_loss: 0.0298 - val_dense_40_loss: 0.1180
#
# Epoch 00050: val_loss did not improve from 0.11565
# Epoch 51/300
# 45000/45000 [==============================] - 194s 4ms/step - loss: 0.0359 - leaky_re_lu_167_loss: 0.0279 - dense_40_loss: 0.0079 - val_loss: 0.1389 - val_leaky_re_lu_167_loss: 0.0278 - val_dense_40_loss: 0.1111
#
# Epoch 00051: val_loss did not improve from 0.11565
# Epoch 52/300
# 45000/45000 [==============================] - 192s 4ms/step - loss: 0.0353 - leaky_re_lu_167_loss: 0.0279 - dense_40_loss: 0.0075 - val_loss: 0.1240 - val_leaky_re_lu_167_loss: 0.0282 - val_dense_40_loss: 0.0959
#
# Epoch 00052: val_loss did not improve from 0.11565
# Epoch 53/300
# 37440/45000 [=======================>......] - ETA: 28s - loss: 0.0348 - leaky_re_lu_167_loss: 0.0278 - dense_40_loss: 0.0070
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-c8b65a67dbf4> in <module>
#       4                     batch_size=batch_size,
#       5                     validation_data=(x_test, [x_test, testlabels]),
# ----> 6                     callbacks=callbacks_list
#       7                    )
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
autoencoder = load_model(filepath)

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(249)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

autoencoder.save('epochs{}_batch{}_{}.h5'.format(n_epochs, batch_size, val_loss[-1]))

# %%
labels_pred = autoencoder.predict(x_test)[1]
for i in range(len(labels_pred)):
    if labels_pred[i] < 0.5:
        labels_pred[i] = 0
    else:
        labels_pred[i] = 1
        
evaluation = metrics.classification_report(testlabels, labels_pred)
print(evaluation)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91      8846
#            1       0.88      0.87      0.88      6154
#
#     accuracy                           0.90     15000
#    macro avg       0.90      0.89      0.90     15000
# weighted avg       0.90      0.90      0.90     15000

# %%
decoded_imgs = autoencoder.predict(x_test)[0]
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt 

layer_name = 'conv2d_116'
intermediate_layer_model = Model(inputs=autoencoder.input,
                                 outputs=autoencoder.get_layer(layer_name).output)

encoded_imgs = intermediate_layer_model.predict(x_test)
print(encoded_imgs.shape)
encoded_imgs = encoded_imgs.reshape((len(x_test),-1))
print(encoded_imgs.shape)
plt.scatter(encoded_imgs[:, 0], encoded_imgs[:, 1])
# Out:
# (15000, 6, 6, 32)
# (15000, 1152)

# %%
pca = PCA(n_components=50)
pcatransformedData = pca.fit_transform(encoded_imgs)
print(pcatransformedData.shape)
plt.scatter(pcatransformedData[:, 0], pcatransformedData[:, 1])
# Out:
# (15000, 50)

# %%
tsne = TSNE(n_components=2)
transformedData = tsne.fit_transform(pcatransformedData)

print(transformedData.shape)
plt.scatter(transformedData[:, 0], transformedData[:, 1])
# Out:
# (15000, 2)

# %%
from sklearn.mixture import GaussianMixture         # 3) Gaussian Mixture Models
gmm = GaussianMixture(n_components=5).fit(transformedData)
gmmlabels_ = gmm.predict(transformedData)
plt.scatter(transformedData[:, 0], transformedData[:, 1], c=gmmlabels_, s=40, cmap='viridis');
