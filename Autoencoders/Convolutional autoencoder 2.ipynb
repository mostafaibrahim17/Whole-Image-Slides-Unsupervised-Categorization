# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, LeakyReLU, BatchNormalization, Conv2DTranspose
from keras.models import Model
from keras import backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model

import numpy as np
from PIL import Image
import os 
from numba import cuda
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.python.client import device_lib

from sklearn.cluster import KMeans
from skimage.color import rgb2hed
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import metrics
# Out:
# Using TensorFlow backend.
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
gpu_options = tf.GPUOptions(allow_growth=True)
custom_config=tf.ConfigProto(log_device_placement=True, allow_soft_placement=True, gpu_options=gpu_options)
custom_config.gpu_options.allocator_type = 'BFC'
custom_config.gpu_options.per_process_gpu_memory_fraction = 0.90
session = tf.InteractiveSession(config=custom_config)

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2761239987345957012, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7730941132
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10513485992670329752
#  physical_device_desc: "device: 0, name: GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
## Data loading 

trainData = "C:/Users/mostafaosama2/Desktop/regressionSet/train"
# trainData = "../../../autoenctrain/train"
testData = "C:/Users/mostafaosama2/Desktop/regressionSet/test"
# testData = "../../../autoenctrain/test"

new_train = []
new_test = []

for filename in os.listdir(trainData):
    if filename.endswith('.tif'):
        image = Image.open(os.path.join(trainData, filename)) 
        new_train.append(np.asarray( image, dtype="uint8" ))

for filename in os.listdir(testData):
    if filename.endswith('.tif'):
        image = Image.open(os.path.join(testData, filename)) 
        new_test.append(np.asarray( image, dtype="uint8" ))

# %%
## Data preprocessing

x_train = np.asarray(new_train)
x_test = np.asarray(new_test)
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
len(x_test)
# Out:
# 20000

# %%
n_epochs = 10000
batch_size = 32
# n_clusters = 4
optimizer = 'adam'
loss = 'mean_squared_error'

input_img = Input(shape=(96, 96, 3))  # adapt this if using `channels_first` image data format

encoder = Conv2D(filters=16, kernel_size=(3,3),strides=1, padding='same')(input_img)#x^2*16
encoder = LeakyReLU()(encoder)
encoder = Conv2D(filters=32, kernel_size=(3,3),strides=1, padding='same')(encoder)#x^2*32
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = Conv2D(filters=64, kernel_size=(3,3),strides=2, padding='same')(encoder)#(x/2)^2*64
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = MaxPooling2D()(encoder)#(x/4)^2*64
encoder = Conv2D(filters=128, kernel_size=(3,3),strides=2, padding='same')(encoder)#(x/8)^2*128
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = MaxPooling2D()(encoder)#(x/16)^2*64
encoder = Conv2D(filters=64, kernel_size=(3,3),strides=1, padding='same')(encoder)#(x/16)^2*64
encoder = LeakyReLU()(encoder)
encoder = BatchNormalization()(encoder)
encoder = Conv2D(filters=32, kernel_size=(3,3),strides=1, padding='same')(encoder)#(x/16)^2*32
encoder = LeakyReLU()(encoder)


bottleneck = Conv2D(filters=16, kernel_size=(1,1),strides=1, padding='same')(encoder)#(x/16)^2*16
bottleneck = LeakyReLU()(bottleneck)


decoder = Conv2D(filters=32, kernel_size=(1,1),strides=1, padding='same')(bottleneck)#(x/16)^2*32
decoder = LeakyReLU()(decoder)
decoder = Conv2D(filters=64, kernel_size=(3,3),strides=1, padding='same')(decoder)#(x/16)^2*64
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D()(decoder)#(x/8)^2*64
decoder = Conv2DTranspose(filters=128, kernel_size=(3,3),strides=2, padding='same')(decoder)#(x/4)^2*128
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D()(decoder)#(x/2)^2*128
decoder = Conv2DTranspose(filters=64, kernel_size=(3,3),strides=2, padding='same')(decoder)#x^2*64
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = Conv2D(filters=32, kernel_size=(3,3),strides=1, padding='same')(decoder)#x^2*32
decoder = LeakyReLU()(decoder)
decoder = BatchNormalization()(decoder)
decoder = Conv2D(filters=16, kernel_size=(3,3),strides=1, padding='same')(decoder)#x^2*16
decoder = LeakyReLU()(decoder)
decoder = Conv2D(filters=3, kernel_size=(3,3),strides=1, padding='same')(decoder)#x^2*3
decoded = LeakyReLU()(decoder)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer=optimizer , loss=loss)

# filepath = "../notebooks/checkpoint_epochs{}_batch{}_{}.h5".format(n_epochs,batch_size,optimizer)
filepath = "C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs{}_batch{}_{}.h5".format(n_epochs,batch_size,optimizer)

checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
ES = EarlyStopping(monitor='loss', min_delta=0, patience=30, verbose=0, mode='min', restore_best_weights=True)

callbacks_list = [checkpoint, ES]

# %%
with tf.device('/GPU:0'):
    autoencoder_train = autoencoder.fit(x_train, x_train,
                    epochs=n_epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(x_test, x_test),
                    callbacks=callbacks_list
                   )
# Out:
# Train on 79998 samples, validate on 20000 samples
# Epoch 1/10000
# 79998/79998 [==============================] - 390s 5ms/step - loss: 0.0325 - val_loss: 0.0296
#
# Epoch 00001: loss improved from inf to 0.03255, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 2/10000
# 79998/79998 [==============================] - 374s 5ms/step - loss: 0.0258 - val_loss: 0.0315
#
# Epoch 00002: loss improved from 0.03255 to 0.02580, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 3/10000
# 79998/79998 [==============================] - 374s 5ms/step - loss: 0.0240 - val_loss: 0.0239
#
# Epoch 00003: loss improved from 0.02580 to 0.02405, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 4/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0228 - val_loss: 0.0226
#
# Epoch 00004: loss improved from 0.02405 to 0.02284, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 5/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0221 - val_loss: 0.0219
#
# Epoch 00005: loss improved from 0.02284 to 0.02206, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 6/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0213 - val_loss: 0.0237
#
# Epoch 00006: loss improved from 0.02206 to 0.02130, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 7/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0200 - val_loss: 0.0196
#
# Epoch 00007: loss improved from 0.02130 to 0.02001, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 8/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0191 - val_loss: 0.0188
#
# Epoch 00008: loss improved from 0.02001 to 0.01915, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 9/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0189 - val_loss: 0.0197
#
# Epoch 00009: loss improved from 0.01915 to 0.01891, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 10/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0188 - val_loss: 0.0185
#
# Epoch 00010: loss improved from 0.01891 to 0.01875, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 11/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0186 - val_loss: 0.0187
#
# Epoch 00011: loss improved from 0.01875 to 0.01861, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 12/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0185 - val_loss: 0.0185
#
# Epoch 00012: loss improved from 0.01861 to 0.01852, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 13/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0182 - val_loss: 0.0180
#
# Epoch 00013: loss improved from 0.01852 to 0.01824, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 14/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0180 - val_loss: 0.0176
#
# Epoch 00014: loss improved from 0.01824 to 0.01801, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 15/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0179 - val_loss: 0.0177
#
# Epoch 00015: loss improved from 0.01801 to 0.01793, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 16/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0178 - val_loss: 0.0178
#
# Epoch 00016: loss improved from 0.01793 to 0.01784, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 17/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0178 - val_loss: 0.0179
#
# Epoch 00017: loss improved from 0.01784 to 0.01779, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 18/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0177 - val_loss: 0.0177
#
# Epoch 00018: loss improved from 0.01779 to 0.01774, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 19/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0177 - val_loss: 0.0176
#
# Epoch 00019: loss improved from 0.01774 to 0.01768, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 20/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0177 - val_loss: 0.0177
#
# Epoch 00020: loss improved from 0.01768 to 0.01765, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 21/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0176 - val_loss: 0.0177
#
# Epoch 00021: loss improved from 0.01765 to 0.01761, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 22/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0176 - val_loss: 0.0174
#
# Epoch 00022: loss improved from 0.01761 to 0.01759, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 23/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0176 - val_loss: 0.0174
#
# Epoch 00023: loss improved from 0.01759 to 0.01756, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 24/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0175 - val_loss: 0.0173
#
# Epoch 00024: loss improved from 0.01756 to 0.01753, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 25/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0175 - val_loss: 0.0173
#
# Epoch 00025: loss improved from 0.01753 to 0.01751, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 26/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0175 - val_loss: 0.0174
#
# Epoch 00026: loss improved from 0.01751 to 0.01750, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 27/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0175 - val_loss: 0.0172
#
# Epoch 00027: loss improved from 0.01750 to 0.01747, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 28/10000
# 79998/79998 [==============================] - 376s 5ms/step - loss: 0.0175 - val_loss: 0.0179
#
# Epoch 00028: loss improved from 0.01747 to 0.01746, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 29/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0174 - val_loss: 0.0175
#
# Epoch 00029: loss improved from 0.01746 to 0.01745, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 30/10000
# 79998/79998 [==============================] - 372s 5ms/step - loss: 0.0174 - val_loss: 0.0177
#
# Epoch 00030: loss improved from 0.01745 to 0.01742, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 31/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0174 - val_loss: 0.0173
#
# Epoch 00031: loss improved from 0.01742 to 0.01742, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 32/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0174 - val_loss: 0.0172
#
# Epoch 00032: loss improved from 0.01742 to 0.01742, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 33/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0174 - val_loss: 0.0174
#
# Epoch 00033: loss improved from 0.01742 to 0.01740, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 34/10000
# 79998/79998 [==============================] - 376s 5ms/step - loss: 0.0174 - val_loss: 0.0174
#
# Epoch 00034: loss improved from 0.01740 to 0.01737, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 35/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0174 - val_loss: 0.0174
#
# Epoch 00035: loss improved from 0.01737 to 0.01736, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 36/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0174 - val_loss: 0.0173
#
# Epoch 00036: loss improved from 0.01736 to 0.01735, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 37/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0173 - val_loss: 0.0171
#
# Epoch 00037: loss improved from 0.01735 to 0.01734, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 38/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0173 - val_loss: 0.0173
#
# Epoch 00038: loss did not improve from 0.01734
# Epoch 39/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0173 - val_loss: 0.0173
#
# Epoch 00039: loss improved from 0.01734 to 0.01732, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 40/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0173 - val_loss: 0.0174
#
# Epoch 00040: loss improved from 0.01732 to 0.01731, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 41/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0173 - val_loss: 0.0171
#
# Epoch 00041: loss improved from 0.01731 to 0.01731, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 42/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0173 - val_loss: 0.0172
#
# Epoch 00042: loss improved from 0.01731 to 0.01730, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 43/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0173 - val_loss: 0.0170
#
# Epoch 00043: loss improved from 0.01730 to 0.01729, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 44/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0173 - val_loss: 0.0172
#
# Epoch 00044: loss improved from 0.01729 to 0.01727, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 45/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0173 - val_loss: 0.0173
#
# Epoch 00045: loss did not improve from 0.01727
# Epoch 46/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0173 - val_loss: 0.0171
#
# Epoch 00046: loss improved from 0.01727 to 0.01726, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 47/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0173 - val_loss: 0.0171
#
# Epoch 00047: loss improved from 0.01726 to 0.01726, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 48/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0173 - val_loss: 0.0172
#
# Epoch 00048: loss improved from 0.01726 to 0.01725, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 49/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0172 - val_loss: 0.0173
#
# Epoch 00049: loss improved from 0.01725 to 0.01724, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 50/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00050: loss did not improve from 0.01724
# Epoch 51/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00051: loss improved from 0.01724 to 0.01723, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 52/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00052: loss improved from 0.01723 to 0.01723, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 53/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00053: loss improved from 0.01723 to 0.01722, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 54/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00054: loss improved from 0.01722 to 0.01721, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 55/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00055: loss did not improve from 0.01721
# Epoch 56/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00056: loss did not improve from 0.01721
# Epoch 57/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00057: loss improved from 0.01721 to 0.01721, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 58/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00058: loss improved from 0.01721 to 0.01720, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 59/10000
# 79998/79998 [==============================] - 383s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00059: loss improved from 0.01720 to 0.01719, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 60/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00060: loss did not improve from 0.01719
# Epoch 61/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0172 - val_loss: 0.0172
#
# Epoch 00061: loss improved from 0.01719 to 0.01718, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 62/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00062: loss did not improve from 0.01718
# Epoch 63/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0172 - val_loss: 0.0172
#
# Epoch 00063: loss improved from 0.01718 to 0.01717, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 64/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00064: loss improved from 0.01717 to 0.01717, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 65/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00065: loss improved from 0.01717 to 0.01717, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 66/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0172 - val_loss: 0.0170
#
# Epoch 00066: loss improved from 0.01717 to 0.01715, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 67/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0172 - val_loss: 0.0169
#
# Epoch 00067: loss did not improve from 0.01715
# Epoch 68/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0172 - val_loss: 0.0172
#
# Epoch 00068: loss improved from 0.01715 to 0.01715, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 69/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0172 - val_loss: 0.0171
#
# Epoch 00069: loss did not improve from 0.01715
# Epoch 70/10000
# 79998/79998 [==============================] - 377s 5ms/step - loss: 0.0171 - val_loss: 0.0171
#
# Epoch 00070: loss improved from 0.01715 to 0.01714, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 71/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0171
#
# Epoch 00071: loss improved from 0.01714 to 0.01714, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 72/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00072: loss improved from 0.01714 to 0.01714, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 73/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00073: loss improved from 0.01714 to 0.01713, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 74/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00074: loss improved from 0.01713 to 0.01713, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 75/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00075: loss did not improve from 0.01713
# Epoch 76/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00076: loss improved from 0.01713 to 0.01712, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 77/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0168
#
# Epoch 00077: loss improved from 0.01712 to 0.01712, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 78/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00078: loss improved from 0.01712 to 0.01711, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 79/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00079: loss improved from 0.01711 to 0.01711, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 80/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00080: loss improved from 0.01711 to 0.01711, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 81/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00081: loss improved from 0.01711 to 0.01710, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 82/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00082: loss did not improve from 0.01710
# Epoch 83/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00083: loss improved from 0.01710 to 0.01709, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 84/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00084: loss did not improve from 0.01709
# Epoch 85/10000
# 79998/79998 [==============================] - 378s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00085: loss did not improve from 0.01709
# Epoch 86/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0172
#
# Epoch 00086: loss improved from 0.01709 to 0.01709, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 87/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00087: loss did not improve from 0.01709
# Epoch 88/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00088: loss improved from 0.01709 to 0.01708, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 89/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00089: loss improved from 0.01708 to 0.01708, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 90/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00090: loss improved from 0.01708 to 0.01708, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 91/10000
# 79998/79998 [==============================] - 383s 5ms/step - loss: 0.0171 - val_loss: 0.0172
#
# Epoch 00091: loss improved from 0.01708 to 0.01708, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 92/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0171
#
# Epoch 00092: loss improved from 0.01708 to 0.01707, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 93/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00093: loss improved from 0.01707 to 0.01707, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 94/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0168
#
# Epoch 00094: loss improved from 0.01707 to 0.01707, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 95/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0169
#
# Epoch 00095: loss did not improve from 0.01707
# Epoch 96/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0171 - val_loss: 0.0168
#
# Epoch 00096: loss improved from 0.01707 to 0.01706, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 97/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00097: loss did not improve from 0.01706
# Epoch 98/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0171 - val_loss: 0.0168
#
# Epoch 00098: loss improved from 0.01706 to 0.01705, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 99/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0171 - val_loss: 0.0170
#
# Epoch 00099: loss did not improve from 0.01705
# Epoch 100/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00100: loss improved from 0.01705 to 0.01705, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 101/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0170
#
# Epoch 00101: loss did not improve from 0.01705
# Epoch 102/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0170
#
# Epoch 00102: loss improved from 0.01705 to 0.01704, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 103/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0168
#
# Epoch 00103: loss improved from 0.01704 to 0.01704, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 104/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0168
#
# Epoch 00104: loss did not improve from 0.01704
# Epoch 105/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0171
#
# Epoch 00105: loss improved from 0.01704 to 0.01704, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 106/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00106: loss improved from 0.01704 to 0.01704, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 107/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00107: loss improved from 0.01704 to 0.01703, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 108/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0170
#
# Epoch 00108: loss improved from 0.01703 to 0.01703, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 109/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00109: loss did not improve from 0.01703
# Epoch 110/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0171
#
# Epoch 00110: loss improved from 0.01703 to 0.01703, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 111/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0172
#
# Epoch 00111: loss improved from 0.01703 to 0.01702, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 112/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00112: loss improved from 0.01702 to 0.01702, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 113/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00113: loss improved from 0.01702 to 0.01702, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 114/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0168
#
# Epoch 00114: loss did not improve from 0.01702
# Epoch 115/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0170 - val_loss: 0.0171
#
# Epoch 00115: loss improved from 0.01702 to 0.01701, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 116/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0170 - val_loss: 0.0168
#
# Epoch 00116: loss improved from 0.01701 to 0.01701, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 117/10000
# 79998/79998 [==============================] - 382s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00117: loss did not improve from 0.01701
# Epoch 118/10000
# 79998/79998 [==============================] - 381s 5ms/step - loss: 0.0170 - val_loss: 0.0169
#
# Epoch 00118: loss improved from 0.01701 to 0.01700, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 119/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0170 - val_loss: 0.0168
#
# Epoch 00119: loss improved from 0.01700 to 0.01700, saving model to C:/Users/mostafaosama2/Desktop/Generalised-WSI-Clustering/notebooks/fulldata_checkpoint_epochs10000_batch32_adam.h5
# Epoch 120/10000
# 79998/79998 [==============================] - 379s 5ms/step - loss: 0.0170 - val_loss: 0.0168
#
# Epoch 00120: loss did not improve from 0.01700
# Epoch 121/10000
# 79998/79998 [==============================] - 380s 5ms/step - loss: 0.0170 - val_loss: 0.0170
#
# Epoch 00121: loss did not improve from 0.01700
# Epoch 122/10000
# 69120/79998 [========================>.....] - ETA: 45s - loss: 0.0170
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bc30fba00522> in <module>
#       5                     shuffle=True,
#       6                     validation_data=(x_test, x_test),
# ----> 7                     callbacks=callbacks_list
#       8                    )
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\users\mostafaosama2\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
autoencoder_train= load_model(filepath)

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(n_epochs)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

autoencoder.save('epochs{}_batch{}_{}_{}.h5'.format(n_epochs, batch_size, optimizer, loss[-1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e973920ae73e> in <module>
# ----> 1 loss = autoencoder_train.history['loss']
#       2 val_loss = autoencoder_train.history['val_loss']
#       3 epochs = range(n_epochs)
#       4 plt.figure()
#       5 plt.plot(epochs, loss, 'bo', label='Training loss')
#
# AttributeError: 'Model' object has no attribute 'history'

# %%
decoded_imgs = autoencoder_train.predict(x_test)
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cuda.select_device(0)
cuda.close()

# %%
autoencoder_train.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 96, 96, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 16)        448
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 96, 96, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 32)        4640
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 64)          73792
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 32)          18464
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 16)          528
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 6, 6, 16)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 32)          544
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 64)          18496
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 24, 24, 128)       73856
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 24, 24, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 48, 48, 128)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 96, 96, 64)        73792
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 96, 96, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 96, 96, 64)        256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 96, 96, 32)        18464
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 96, 96, 16)        4624
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 96, 96, 16)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 96, 96, 3)         435
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 96, 96, 3)         0
# =================================================================
# Total params: 382,739
# Trainable params: 381,587
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt 

layer_name = 'conv2d_7'
intermediate_layer_model = Model(inputs=autoencoder.input,
                                 outputs=autoencoder.get_layer(layer_name).output)

encoded_imgs = intermediate_layer_model.predict(x_test)
print(encoded_imgs.shape)
encoded_imgs = encoded_imgs.reshape((len(x_test),-1))
print(encoded_imgs.shape)
plt.scatter(encoded_imgs[:, 0], encoded_imgs[:, 1])
# Out:
# (20000, 6, 6, 16)
# (20000, 576)

# %%
pca = PCA(n_components=50)
pcatransformedData = pca.fit_transform(encoded_imgs)
print(pcatransformedData.shape)
plt.scatter(pcatransformedData[:, 0], pcatransformedData[:, 1])
# Out:
# (20000, 50)

# %%
tsne = TSNE(n_components=2)
transformedData = tsne.fit_transform(pcatransformedData)

print(transformedData.shape)
plt.scatter(transformedData[:, 0], transformedData[:, 1])
# Out:
# (20000, 2)
